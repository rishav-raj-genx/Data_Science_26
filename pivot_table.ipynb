# %% [markdown]
# <a href="https://colab.research.google.com/github/rishav-raj-genx/Data_Science_26/blob/main/pivot_table.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
do = pd.read_csv('student_data.csv')

# %%
do.pivot_table(columns = 'placement_status', index = 'sleep_hours', values = 'exam_score', aggfunc = 'mean')
# Out:
# placement_status  Not Placed     Placed
# sleep_hours
# 4                  59.424160  90.483113
# 5                  58.306079  91.085519
# 6                  60.971968  91.819595
# 7                  59.650121  92.279986
# 8                  60.091122  93.062072
# 9                  61.181129  92.987227

# %%
df = pd.read_csv('student_data.csv')

# %%
df.pivot_table(columns = 'study_hours', index = 'sleep_hours', values = 'exam_score', aggfunc = 'mean')
