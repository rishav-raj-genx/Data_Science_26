# %% [markdown]
# <a href="https://colab.research.google.com/github/rishav-raj-genx/Data_Science_26/blob/main/OOPs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class student:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def display(self):
      print('Name:', self.name)
      print('Age:', self.age)

a = student('Jhon', 20)
a.display()
# Out:
# Name: Jhon
# Age: 20
