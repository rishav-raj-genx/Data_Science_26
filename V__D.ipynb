# %% [markdown]
# <a href="https://colab.research.google.com/github/rishav-raj-genx/Data_Science_26/blob/main/V__D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('student_data.csv')

# %%
df.groupby('placement_status')['placement_status'].agg('count')
# Out:
# placement_status
# Not Placed    1644
# Placed        8356
# Name: placement_status, dtype: int64

# %%
df.groupby('placement_status')['exam_score'].agg('mean')
# Out:
# placement_status
# Not Placed    59.804653
# Placed        91.996556
# Name: exam_score, dtype: float64
